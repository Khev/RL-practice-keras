# %% [markdown]
# # Introduction
#
# Here I'm figured out how tensorboard works, from http://fizzylogic.nl/2017/05/08/monitor-progress-of-your-keras-based-neural-network-using-tensorboard/

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import TensorBoard
import time
# Out:
# /home/kokeeffe/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Load in sample data --- from https://machinelearningmastery.com/generate-test-datasets-python-scikit-learn/

from sklearn.datasets.samples_generator import make_blobs
from pandas import DataFrame
X, y = make_blobs(n_samples=1000, centers=3, n_features=2)

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = plt.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

# %%
#Back to the tutorial --- first get bearings
index = int(0.9*len(X))
x_train, y_train = X[:index],y[:index]
x_test, y_test = X[index:], y[index:]
input_dim = X.shape[1]
output_dim = 1

model = Sequential()
model.add(Dense(5, input_dim=input_dim,activation = 'relu'))
model.add(Dense(5, activation = 'relu'))
model.add(Dense(output_dim,activation='linear'))
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(x_train, y_train, verbose=1)
# Out:
# Epoch 1/1
# 900/900 [==============================] - 0s 142us/step - loss: 0.8256

# %%
y_pred = model.predict_on_batch(x_test)
y_pred = np.round(y_pred)
y_pred.resize(len(y_pred))

sum(y_pred == y_test) / (1.0*len(y_test))
# Out:
# 0.94

# %% [markdown]
# ### Now use tensorboard

# %%
index = int(0.9*len(X))
x_train, y_train = X[:index],y[:index]
x_test, y_test = X[index:], y[index:]
input_dim = X.shape[1]
output_dim = 1

#Define model
model = Sequential()
model.add(Dense(100, input_dim=input_dim,activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(output_dim,activation='linear'))
model.compile(optimizer='sgd', loss='mean_squared_error')

#Add in tensor board
tensorboard = TensorBoard(log_dir='./logs', histogram_freq=0,
                          write_graph=True, write_images=False, write_grads=True)

model.fit(x_train,y_train,epochs=10000,verbose=1,callbacks=[tensorboard])
# Out:
# Epoch 1/10000
# 900/900 [==============================] - 0s 97us/step - loss: 0.1226
# Epoch 2/10000
# 900/900 [==============================] - 0s 47us/step - loss: 0.0450
# Epoch 3/10000
# 900/900 [==============================] - 0s 39us/step - loss: 0.0407
# Epoch 4/10000
# 900/900 [==============================] - 0s 54us/step - loss: 0.0392
# Epoch 5/10000
# 900/900 [==============================] - 0s 34us/step - loss: 0.0378
# Epoch 6/10000
# 900/900 [==============================] - 0s 37us/step - loss: 0.0372
# Epoch 7/10000
# 900/900 [==============================] - 0s 33us/step - loss: 0.0349
# Epoch 8/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0339
# Epoch 9/10000
# 900/900 [==============================] - 0s 22us/step - loss: 0.0326
# Epoch 10/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0329
# Epoch 11/10000
# 900/900 [==============================] - 0s 37us/step - loss: 0.0308
# Epoch 12/10000
# 900/900 [==============================] - 0s 41us/step - loss: 0.0305
# Epoch 13/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0292
# Epoch 14/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0294
# Epoch 15/10000
# 900/900 [==============================] - 0s 44us/step - loss: 0.0271
# Epoch 16/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0268
# Epoch 17/10000
# 900/900 [==============================] - 0s 26us/step - loss: 0.0257
# Epoch 18/10000
# 900/900 [==============================] - 0s 24us/step - loss: 0.0259
# Epoch 19/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0249
# Epoch 20/10000
# 900/900 [==============================] - 0s 39us/step - loss: 0.0240
# Epoch 21/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0235
# Epoch 22/10000
# 900/900 [==============================] - 0s 27us/step - loss: 0.0246
# Epoch 23/10000
# 900/900 [==============================] - 0s 34us/step - loss: 0.0226
# Epoch 24/10000
# 900/900 [==============================] - 0s 40us/step - loss: 0.0217
# Epoch 25/10000
# 900/900 [==============================] - 0s 44us/step - loss: 0.0213
# Epoch 26/10000
# 900/900 [==============================] - 0s 38us/step - loss: 0.0210
# Epoch 27/10000
# 900/900 [==============================] - 0s 37us/step - loss: 0.0207
# Epoch 28/10000
# 900/900 [==============================] - 0s 27us/step - loss: 0.0199
# Epoch 29/10000
# 900/900 [==============================] - 0s 41us/step - loss: 0.0192
# Epoch 30/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0193
# Epoch 31/10000
# 900/900 [==============================] - 0s 33us/step - loss: 0.0184
# Epoch 32/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0179
# Epoch 33/10000
# 900/900 [==============================] - 0s 55us/step - loss: 0.0175
# Epoch 34/10000
# 900/900 [==============================] - 0s 41us/step - loss: 0.0173
# Epoch 35/10000
# 900/900 [==============================] - 0s 39us/step - loss: 0.0169
# Epoch 36/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0166
# Epoch 37/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0171
# Epoch 38/10000
# 900/900 [==============================] - 0s 41us/step - loss: 0.0167
# Epoch 39/10000
# 900/900 [==============================] - 0s 43us/step - loss: 0.0152
# Epoch 40/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0154
# Epoch 41/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0148
# Epoch 42/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0144
# Epoch 43/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0141
# Epoch 44/10000
# 900/900 [==============================] - 0s 43us/step - loss: 0.0140
# Epoch 45/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0139
# Epoch 46/10000
# 900/900 [==============================] - 0s 37us/step - loss: 0.0140
# Epoch 47/10000
# 900/900 [==============================] - 0s 43us/step - loss: 0.0129
# Epoch 48/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0133
# Epoch 49/10000
# 900/900 [==============================] - 0s 43us/step - loss: 0.0126
# Epoch 50/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0128
# Epoch 51/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0117
# Epoch 52/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0117
# Epoch 53/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0116
# Epoch 54/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0111
# Epoch 55/10000
# 900/900 [==============================] - 0s 52us/step - loss: 0.0112
# Epoch 56/10000
# 900/900 [==============================] - 0s 39us/step - loss: 0.0106
# Epoch 57/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0106
# Epoch 58/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0106
# Epoch 59/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0099
# Epoch 60/10000
# 900/900 [==============================] - 0s 34us/step - loss: 0.0100
# Epoch 61/10000
# 900/900 [==============================] - 0s 27us/step - loss: 0.0103
# Epoch 62/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0097
# Epoch 63/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0095
# Epoch 64/10000
# 900/900 [==============================] - 0s 41us/step - loss: 0.0092
# Epoch 65/10000
# 900/900 [==============================] - 0s 54us/step - loss: 0.0091
# Epoch 66/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0090
# Epoch 67/10000
# 900/900 [==============================] - 0s 33us/step - loss: 0.0089
# Epoch 68/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0087
# Epoch 69/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0087
# Epoch 70/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0084
# Epoch 71/10000
# 900/900 [==============================] - 0s 21us/step - loss: 0.0086
# Epoch 72/10000
# 900/900 [==============================] - 0s 38us/step - loss: 0.0080
# Epoch 73/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0081
# Epoch 74/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0080
# Epoch 75/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0077
# Epoch 76/10000
# 900/900 [==============================] - 0s 34us/step - loss: 0.0078
# Epoch 77/10000
# 900/900 [==============================] - 0s 34us/step - loss: 0.0075
# Epoch 78/10000
# 900/900 [==============================] - 0s 42us/step - loss: 0.0074
# Epoch 79/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0070
# Epoch 80/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0073
# Epoch 81/10000
# 900/900 [==============================] - 0s 38us/step - loss: 0.0068
# Epoch 82/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0068
# Epoch 83/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0072
# Epoch 84/10000
# 900/900 [==============================] - 0s 38us/step - loss: 0.0065
# Epoch 85/10000
# 900/900 [==============================] - 0s 32us/step - loss: 0.0066
# Epoch 86/10000
# 900/900 [==============================] - 0s 44us/step - loss: 0.0065
# Epoch 87/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0065
# Epoch 88/10000
# 900/900 [==============================] - 0s 36us/step - loss: 0.0062
# Epoch 89/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0064
# Epoch 90/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0061
# Epoch 91/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0059
# Epoch 92/10000
# 900/900 [==============================] - 0s 33us/step - loss: 0.0059
# Epoch 93/10000
# 900/900 [==============================] - 0s 34us/step - loss: 0.0063
# Epoch 94/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0058
# Epoch 95/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0059
# Epoch 96/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0067
# Epoch 97/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0054
# Epoch 98/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0052
# Epoch 99/10000
# 900/900 [==============================] - 0s 26us/step - loss: 0.0057
# Epoch 100/10000
# 900/900 [==============================] - 0s 27us/step - loss: 0.0054
# Epoch 101/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0050
# Epoch 102/10000
# 900/900 [==============================] - 0s 24us/step - loss: 0.0050
# Epoch 103/10000
# 900/900 [==============================] - 0s 35us/step - loss: 0.0050
# Epoch 104/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0050
# Epoch 105/10000
# 900/900 [==============================] - 0s 32us/step - loss: 0.0049
# Epoch 106/10000
# 900/900 [==============================] - 0s 24us/step - loss: 0.0047
# Epoch 107/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0049
# Epoch 108/10000
# 900/900 [==============================] - 0s 31us/step - loss: 0.0048
# Epoch 109/10000
# 900/900 [==============================] - 0s 26us/step - loss: 0.0048
# Epoch 110/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0048
# Epoch 111/10000
# 900/900 [==============================] - 0s 26us/step - loss: 0.0044
# Epoch 112/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0046
# Epoch 113/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0045
# Epoch 114/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0045
# Epoch 115/10000
# 900/900 [==============================] - 0s 32us/step - loss: 0.0043
# Epoch 116/10000
# 900/900 [==============================] - 0s 26us/step - loss: 0.0045
# Epoch 117/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0044
# Epoch 118/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0041
# Epoch 119/10000
# 900/900 [==============================] - 0s 24us/step - loss: 0.0043
# Epoch 120/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0040
# Epoch 121/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0039
# Epoch 122/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0041
# Epoch 123/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0040
# Epoch 124/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0039
# Epoch 125/10000
# 900/900 [==============================] - 0s 29us/step - loss: 0.0038
# Epoch 126/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0038
# Epoch 127/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0038
# Epoch 128/10000
# 900/900 [==============================] - 0s 25us/step - loss: 0.0051
# Epoch 129/10000
# 900/900 [==============================] - 0s 27us/step - loss: 0.0037
# Epoch 130/10000
# 900/900 [==============================] - 0s 30us/step - loss: 0.0042
# Epoch 131/10000
# 900/900 [==============================] - 0s 28us/step - loss: 0.0038
# Epoch 132/10000
#  32/900 [>.............................] - ETA: 0s - loss: 0.0070
