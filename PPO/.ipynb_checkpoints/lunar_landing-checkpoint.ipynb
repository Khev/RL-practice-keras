# %% [markdown]
# ### Introduction
#
# Here I'm testing code from the PPO algorithm. I'm following the code from
#
# https://github.com/germain-hug/Deep-RL-Keras/blob/master/A2C/
#
# Note: I haven't implemented the temporal difference part yet. So, this is really just policy gradient with
# a baseline state-value function (which I model with another, separate, neural net -- do other people do this? I must check).

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from agent_with_baseline import Agent
from keras.utils import to_categorical
# %matplotlib inline


EPISODES = 10000

env = gym.make('LunarLander-v2')
env.seed(1)  # for comparison
num_states = env.observation_space.shape[0]
num_actions = env.action_space.n
agent = Agent(num_states, num_actions)
agent.gamma = 0.99
agent.lr = 0.01

scores = []

for e in range(1,EPISODES+1):
    state = env.reset()
    state = np.reshape(state, [1, num_states])
    reward_sum = 0
    done = False
    while not done:
        # env.render()
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        reward_sum += reward
        next_state = np.reshape(next_state, [1, num_states])
        agent.remember(state[0], action, reward)
        state = next_state
        if done:
            break
    
    #Learn & print results
    agent.train_models()
    scores.append(reward_sum)
    if e % 50 == 0:
        print '(episode, score) = ' + str((e,reward_sum))

plt.plot(scores)
np.savetxt('stats/scores_lunar_landing.txt',scores)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <type 'numpy.float32'>. Please provide explicit dtype.
# (episode, score) = (50, -262.4324570456664)
# (episode, score) = (100, -417.78919361453273)
# (episode, score) = (150, -96.21508126286244)
# (episode, score) = (200, -151.31026599095537)
# (episode, score) = (250, -155.83939042080954)
# (episode, score) = (300, -196.46334923135356)
# (episode, score) = (350, -361.87214607428075)
# (episode, score) = (400, -201.07679523194346)
# (episode, score) = (450, -265.2329012528403)
# (episode, score) = (500, -76.14559181199824)
# (episode, score) = (550, -84.43942515897939)
# (episode, score) = (600, -184.6699681170196)
# (episode, score) = (650, -97.72077852227248)
# (episode, score) = (700, -165.8007290055861)
# (episode, score) = (750, -79.31815618430784)
# (episode, score) = (800, -172.97029518329623)
# (episode, score) = (850, -62.35772615987008)
# (episode, score) = (900, -232.7058815903016)
# (episode, score) = (950, -67.48392677601453)
# (episode, score) = (1000, -90.94231109028358)
# (episode, score) = (1050, -14.9801729754044)
# (episode, score) = (1100, -300.40312385454536)
# (episode, score) = (1150, -240.07250099011185)
# (episode, score) = (1200, -117.84151658483658)
# (episode, score) = (1250, -15.334078820279444)
# (episode, score) = (1300, -116.44549451486257)
# (episode, score) = (1350, 15.21598595451669)
# (episode, score) = (1400, -60.45317233001923)
# (episode, score) = (1450, -44.02736520968953)
# (episode, score) = (1500, -29.776378744584672)
# (episode, score) = (1550, -256.76728782058467)
# (episode, score) = (1600, -88.58454694568866)
# (episode, score) = (1650, -64.20578374677233)
# (episode, score) = (1700, 11.602232580666383)
# (episode, score) = (1750, 36.358624845142174)
# (episode, score) = (1800, 72.47454945989118)
# (episode, score) = (1850, 26.208377793965028)
# (episode, score) = (1900, -46.3142142783729)
# (episode, score) = (1950, 26.0720275430453)
# (episode, score) = (2000, -47.286764234468606)
# (episode, score) = (2050, 29.632525627113953)
# (episode, score) = (2100, 61.41768881062403)
# (episode, score) = (2150, -13.350448697888352)
# (episode, score) = (2200, 6.1330718745313995)
# (episode, score) = (2250, 77.7842123794449)
# (episode, score) = (2300, -118.72403581018312)
# (episode, score) = (2350, -3.64182600331391)
# (episode, score) = (2400, -27.342873300006858)
# (episode, score) = (2450, 68.89287649864495)
# (episode, score) = (2500, 52.31413039131442)
# (episode, score) = (2550, 79.60092372441696)
# (episode, score) = (2600, 53.3821077627588)
# (episode, score) = (2650, 33.04609374348792)
# (episode, score) = (2700, 51.893942949324526)
# (episode, score) = (2750, 78.23036508755538)
# (episode, score) = (2800, 81.66012635281356)
# (episode, score) = (2850, 85.09410295549213)
# (episode, score) = (2900, -18.329345984303274)
# (episode, score) = (2950, 95.98809997873536)
# (episode, score) = (3000, 10.93434175674885)
# (episode, score) = (3050, 91.64561475671408)
# (episode, score) = (3100, 86.73074873616997)
# (episode, score) = (3150, -27.33246073290131)
# (episode, score) = (3200, -2.441551829727345)
# (episode, score) = (3250, 15.078264676149075)
# (episode, score) = (3300, 70.94275219295845)
# (episode, score) = (3350, 55.80934399811074)
# (episode, score) = (3400, 124.16026140998117)
# (episode, score) = (3450, 76.45733809234096)
# (episode, score) = (3500, 100.3131035883194)
# (episode, score) = (3550, 83.1319659040896)
# (episode, score) = (3600, 116.35153698123497)
# (episode, score) = (3650, 24.986937962221575)
# (episode, score) = (3700, -17.44104608920459)
# (episode, score) = (3750, -10.266798972186308)
# (episode, score) = (3800, -32.41636814634484)
# (episode, score) = (3850, 35.44457675140325)
# (episode, score) = (3900, 17.126575607534676)
# (episode, score) = (3950, 126.58814744941255)
# (episode, score) = (4000, 92.33871187540042)
# (episode, score) = (4050, 0.9990533552205818)
# (episode, score) = (4100, 76.08653956492876)
# (episode, score) = (4150, 80.7348907297233)
# (episode, score) = (4200, 131.72619347392578)
# (episode, score) = (4250, 65.09430047206432)
# (episode, score) = (4300, 144.35646625796107)
# (episode, score) = (4350, 82.9107380602337)
# (episode, score) = (4400, 71.5754397234449)
# (episode, score) = (4450, 77.5848900505288)
# (episode, score) = (4500, -21.177198338221416)
# (episode, score) = (4550, 81.8614307452642)
# (episode, score) = (4600, 41.846703808084214)
# (episode, score) = (4650, 39.878375018660606)
# (episode, score) = (4700, 117.954165832991)
# (episode, score) = (4750, 82.34821704840034)
# (episode, score) = (4800, 68.33573351456305)
# (episode, score) = (4850, 105.69087472262473)
# (episode, score) = (4900, 91.51592625752353)
# (episode, score) = (4950, 86.57487686641846)
# (episode, score) = (5000, 101.43228290587886)
# (episode, score) = (5050, 129.11074244150407)
# (episode, score) = (5100, 100.68278059644918)
# (episode, score) = (5150, 94.7617521784961)
# (episode, score) = (5200, 107.31653624666272)
# (episode, score) = (5250, 82.08143222484209)
# (episode, score) = (5300, 114.5005064471508)
# (episode, score) = (5350, 71.66568443653294)
# (episode, score) = (5400, 54.76174734849851)
# (episode, score) = (5450, 110.6608078130819)
# (episode, score) = (5500, 103.1307755713754)
# (episode, score) = (5550, 74.29867754313847)
# (episode, score) = (5600, 99.2196778653703)
# (episode, score) = (5650, 100.06748666824183)
# (episode, score) = (5700, 107.45346974936635)
# (episode, score) = (5750, 91.78020844195426)
# (episode, score) = (5800, 104.0142947568338)
# (episode, score) = (5850, -19.7181535851752)
# (episode, score) = (5900, 64.42695900551732)
# (episode, score) = (5950, 57.695518088842604)
# (episode, score) = (6000, 70.791084112161)
# (episode, score) = (6050, 56.146528409528045)
# (episode, score) = (6100, 52.848059289147045)
# (episode, score) = (6150, 68.05981400435076)
# (episode, score) = (6200, 94.11362793526789)
# (episode, score) = (6250, 65.26431257519185)
# (episode, score) = (6300, 19.18389517091677)
# (episode, score) = (6350, 80.93450112369857)
# (episode, score) = (6400, 128.81061032428093)
# (episode, score) = (6450, 107.33124396110247)
# (episode, score) = (6500, 79.0975790323518)
# (episode, score) = (6550, 0.7409553017210715)
# (episode, score) = (6600, 55.81795413604902)
# (episode, score) = (6650, 95.21191786350316)
# (episode, score) = (6700, 63.64798049032413)
# (episode, score) = (6750, 93.9147082875345)
# (episode, score) = (6800, 76.4776510253504)
# (episode, score) = (6850, 135.80923360417833)
# (episode, score) = (6900, 14.655961371880835)
# (episode, score) = (6950, 131.18316160572257)
# (episode, score) = (7000, 120.56573458078485)
# (episode, score) = (7050, 100.48071797262334)
# (episode, score) = (7100, 78.3101468603879)
# (episode, score) = (7150, 116.11938608051028)
# (episode, score) = (7200, 73.92642250062582)
# (episode, score) = (7250, 105.5761443479672)
# (episode, score) = (7300, 64.3322815469396)
# (episode, score) = (7350, 96.51525029324807)
# (episode, score) = (7400, 94.58651309110144)
# (episode, score) = (7450, 108.55533349545996)
# (episode, score) = (7500, 79.36301441981878)
# (episode, score) = (7550, 68.52378136338339)
# (episode, score) = (7600, 46.532697760609345)
# (episode, score) = (7650, 108.3321556056841)
# (episode, score) = (7700, 58.46687723708237)
# (episode, score) = (7750, 120.04567749897338)
# (episode, score) = (7800, 112.73840258777904)
# (episode, score) = (7850, 147.98153565737775)
# (episode, score) = (7900, 95.49699047902656)
# (episode, score) = (7950, 133.25938375472668)
# (episode, score) = (8000, 107.51283121142525)
# (episode, score) = (8050, 92.30818740665788)
# (episode, score) = (8100, 150.6211990314782)
# (episode, score) = (8150, 127.75345426455144)
# (episode, score) = (8200, 96.26311133061189)
# (episode, score) = (8250, 130.052174165083)
# (episode, score) = (8300, 122.66352804042185)
# (episode, score) = (8350, 76.12627850799689)
# (episode, score) = (8400, 98.02435149432185)
# (episode, score) = (8450, 85.98645612761226)
# (episode, score) = (8500, -20.28503599186726)
# (episode, score) = (8550, 47.53558365132103)
# (episode, score) = (8600, 94.3564037899307)
# (episode, score) = (8650, 68.8164901965728)
# (episode, score) = (8700, 72.43198857666694)
# (episode, score) = (8750, 134.28268634571418)
# (episode, score) = (8800, 13.72548869765555)
# (episode, score) = (8850, 73.45533865232278)
# (episode, score) = (8900, 46.2077448588861)
# (episode, score) = (8950, -11.380786442901268)
# (episode, score) = (9000, -8.095834661874093)
# (episode, score) = (9050, 130.0426055063053)
# (episode, score) = (9100, 104.37878251258924)
# (episode, score) = (9150, 65.58340214661098)
# (episode, score) = (9200, 55.69930140713905)
# (episode, score) = (9250, 72.8621609397507)
# (episode, score) = (9300, 76.00972988432754)
# (episode, score) = (9350, 92.341027484092)
# (episode, score) = (9400, 75.03899053981681)
# (episode, score) = (9450, 74.28792028415218)
# (episode, score) = (9500, 105.60105802600336)
# (episode, score) = (9550, 37.21251561846115)
# (episode, score) = (9600, 96.97543006210385)
# (episode, score) = (9650, 127.14241800241274)
# (episode, score) = (9700, 111.02707231810425)
# (episode, score) = (9750, 77.2878332758305)
# (episode, score) = (9800, 75.42467222746545)
# (episode, score) = (9850, 81.10366625314572)
# (episode, score) = (9900, 66.21706247565595)
# (episode, score) = (9950, 111.76850401800819)
# (episode, score) = (10000, 63.98015025908977)

# %% [markdown]
# Must compare to regular policy gradient
#
#
# ### Compare to regular policy gradients

# %%
#I computed the scores for the regular policy gradient in the, well, 'policy-gradient' foldee ;P
filename = '/home/kokeeffe/research/robocab/RL_practice/policy_gradients/stats/scores_lunar_landing.txt'
scores_regular = np.loadtxt(filename)
plt.plot(scores_regular)
plt.plot(scores)
plt.legend(['without baseline','with baseline'])

# %% [markdown]
# Looks good -- there is indeed smaller variance.

# %% [markdown]
# ### Watch a smart agent

# %%
state = env.reset()
state = np.reshape(state, [1, num_states])
reward_sum = 0
done = False
while not done:
    env.render()
    action = agent.act(state)
    next_state, reward, done, _ = env.step(action)
    reward_sum += reward
    next_state = np.reshape(next_state, [1, num_states])
    agent.remember(state[0], action, reward)
    state = next_state
env.close()
