# %% [markdown]
# # Introduction
#
# Here I'm testing the A2C on the taxi grid graph
#
#
# ### First test the optimal cab

# %%
import networkx as nx
import csv
import copy
import funcs as f
import numpy as np
import matplotlib.pyplot as plt
import gym
from agent_taxi import Agent
from agent_taxi import PolicyCab
from taxi_environment import Env
from keras.utils import to_categorical
# %matplotlib inline



#Environment
n = 4
G = f.make_G(n)
state_zero = np.array([1 if i == 0 else 0 for i in range(G.number_of_nodes())])
env = Env(G,state_zero)


#Agent
p = np.array([G.nodes[i]['prob'] for i in range(G.number_of_nodes())])
optimal_policy = f.find_optimal_policy(p,G)
model_cab = PolicyCab(optimal_policy,G)

taus = []
num_episodes, time_per_episode = 10, 10**4
for episode in range(num_episodes):
    
    state = state_zero
    while model_cab.active_time <= time_per_episode:
        action = model_cab.act(state)
        next_state, reward = env.step(action,model_cab)
        state = next_state
    tau = model_cab.find_tau()
    taus.append(tau)
    print '(episode, tau) = ' + str((episode,model_cab.find_tau()))
    model_cab.reset_clocks()
tau_optimal = np.mean(taus)
# Out:
# /home/kokeeffe/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# (episode, tau) = (0, 0.15978402159784022)
# (episode, tau) = (1, 0.15928407159284072)
# (episode, tau) = (2, 0.1628837116288371)
# (episode, tau) = (3, 0.15328467153284672)
# (episode, tau) = (4, 0.1593840615938406)
# (episode, tau) = (5, 0.15678432156784322)
# (episode, tau) = (6, 0.15398460153984603)
# (episode, tau) = (7, 0.15158484151584842)
# (episode, tau) = (8, 0.1483851614838516)
# (episode, tau) = (9, 0.15698430156984303)

# %% [markdown]
# ### Random cab

# %%
#Environment
n = 4
G = f.make_G(n)
state_zero = np.array([1 if i == 0 else 0 for i in range(G.number_of_nodes())])
env = Env(G,state_zero)


#Agent
p = np.array([G.nodes[i]['prob'] for i in range(G.number_of_nodes())])
optimal_policy = f.find_optimal_policy(p,G)
model_cab = PolicyCab(optimal_policy,G)


num_episodes, time_per_episode = 10, 10**4
taus = []
for episode in range(num_episodes):
    
    state = state_zero
    while model_cab.active_time <= time_per_episode:
        state_scalar = np.where(state==1)[0][0]
        neighbours = G[state_scalar].keys()
        action = np.random.choice(range(len(neighbours)))
        next_state, reward = env.step(action,model_cab)
        state = next_state
    tau = model_cab.find_tau()
    taus.append(tau)
    print '(episode, tau) = ' + str((episode,tau))
    model_cab.reset_clocks()
tau_random = np.mean(taus)
# Out:
# (episode, tau) = (0, 0.25607439256074394)
# (episode, tau) = (1, 0.25877412258774124)
# (episode, tau) = (2, 0.24447555244475552)
# (episode, tau) = (3, 0.252974702529747)
# (episode, tau) = (4, 0.24857514248575144)
# (episode, tau) = (5, 0.2425757424257574)
# (episode, tau) = (6, 0.251974802519748)
# (episode, tau) = (7, 0.24017598240175983)
# (episode, tau) = (8, 0.24847515248475152)
# (episode, tau) = (9, 0.2702729727027297)

# %% [markdown]
# ### RL agent

# %%
EPISODES = 10000


#Environment
n = 4
G = f.make_G(n)
state_zero = np.array([1 if i == 0 else 0 for i in range(G.number_of_nodes())])
env = Env(G,state_zero)
num_states = env.num_states
num_actions = env.num_actions

#Agent
lr = 0.01
gamma = 0.99
agent = Agent(num_states, num_actions, lr, gamma)
agent.memory_size = 1000

scores = []

for e in range(1,EPISODES+1):
    state = state_zero
    state = np.reshape(state, [1, num_states])
    reward_sum = 0
    done = False
    while agent.active_time < 100:
        
        # env.render()
        action = agent.act(state)
        next_state, reward = env.step(action,agent)
        reward_sum += reward
        next_state = np.reshape(next_state, [1, num_states])
        
        #We only want to remember action taken when looking
        if agent.state == 'serving':
            pass
        else:
            agent.remember(state[0], action, 1.0*reward)
        state = next_state
        if done:
            break
    
    #Learn & print results
    agent.train_models()
    tau = agent.find_tau()
    scores.append(tau)
    agent.reset_clocks()
    if e % 50 == 0:
        print '(episode, tau, score) = ' + str((e,tau,reward_sum))

plt.plot(scores)
plt.plot([tau_random for i in scores],'g-')
plt.plot([tau_optimal for i in scores],'r-')
#np.savetxt('stats/scores_lunar_landing.txt',scores)
# Out:
# (episode, tau, score) = (50, 0.26, -5984)
# (episode, tau, score) = (100, 0.32, -5998)
# (episode, tau, score) = (150, 0.3, -6993)
# (episode, tau, score) = (200, 0.25, -1991)
# (episode, tau, score) = (250, 0.09, -968)
# (episode, tau, score) = (300, 0.22, 10)
# (episode, tau, score) = (350, 0.22, 12)
# (episode, tau, score) = (400, 0.25, 7)
# (episode, tau, score) = (450, 0.17, -1979)
# (episode, tau, score) = (500, 0.28, -993)
# (episode, tau, score) = (550, 0.24, 10)
# (episode, tau, score) = (600, 0.22, 16)
# (episode, tau, score) = (650, 0.12, 30)
# (episode, tau, score) = (700, 0.3, 4)
# (episode, tau, score) = (750, 0.24, 12)
# (episode, tau, score) = (800, 0.28, 10)
# (episode, tau, score) = (850, 0.24, 8)
# (episode, tau, score) = (900, 0.21, 15)
# (episode, tau, score) = (950, 0.27, 9)
# (episode, tau, score) = (1000, 0.12, 26)
# (episode, tau, score) = (1050, 0.21, 15)
# (episode, tau, score) = (1100, 0.24, 8)
# (episode, tau, score) = (1150, 0.28, 4)
# (episode, tau, score) = (1200, 0.21, 15)
# (episode, tau, score) = (1250, 0.27, 7)
# (episode, tau, score) = (1300, 0.2, 18)
# (episode, tau, score) = (1350, 0.35, -5)
# (episode, tau, score) = (1400, 0.2, 18)
# (episode, tau, score) = (1450, 0.19, 21)
# (episode, tau, score) = (1500, 0.26, 4)
# (episode, tau, score) = (1550, 0.24, 14)
# (episode, tau, score) = (1600, 0.31, 3)
# (episode, tau, score) = (1650, 0.29, 3)
# (episode, tau, score) = (1700, 0.21, 13)
# (episode, tau, score) = (1750, 0.22, 14)
# (episode, tau, score) = (1800, 0.25, 11)
# (episode, tau, score) = (1850, 0.32, 0)
# (episode, tau, score) = (1900, 0.16, 24)
# (episode, tau, score) = (1950, 0.26, 2)
# (episode, tau, score) = (2000, 0.23, 13)
# (episode, tau, score) = (2050, 0.23, 15)
# (episode, tau, score) = (2100, 0.25, 5)
# (episode, tau, score) = (2150, 0.31, -3)
# (episode, tau, score) = (2200, 0.21, 17)
# (episode, tau, score) = (2250, 0.19, 17)
# (episode, tau, score) = (2300, 0.14, 30)
# (episode, tau, score) = (2350, 0.25, 11)
# (episode, tau, score) = (2400, 0.17, 19)
# (episode, tau, score) = (2450, 0.27, 7)
# (episode, tau, score) = (2500, 0.37, -5)
# (episode, tau, score) = (2550, 0.16, 20)
# (episode, tau, score) = (2600, 0.24, 10)
# (episode, tau, score) = (2650, 0.23, 9)
# (episode, tau, score) = (2700, 0.29, 7)
# (episode, tau, score) = (2750, 0.21, 15)
# (episode, tau, score) = (2800, 0.34, -2)
# (episode, tau, score) = (2850, 0.25, 11)
# (episode, tau, score) = (2900, 0.27, 7)
# (episode, tau, score) = (2950, 0.36, -8)
# (episode, tau, score) = (3000, 0.27, 9)
# (episode, tau, score) = (3050, 0.18, 16)
# (episode, tau, score) = (3100, 0.21, 13)
# (episode, tau, score) = (3150, 0.36, -4)
# (episode, tau, score) = (3200, 0.2, 20)
# (episode, tau, score) = (3250, 0.26, 8)
# (episode, tau, score) = (3300, 0.27, 9)
# (episode, tau, score) = (3350, 0.2, 18)
# (episode, tau, score) = (3400, 0.27, 7)
# (episode, tau, score) = (3450, 0.22, 12)
# (episode, tau, score) = (3500, 0.25, 5)
# (episode, tau, score) = (3550, 0.36, -6)
# (episode, tau, score) = (3600, 0.24, 8)
# (episode, tau, score) = (3650, 0.23, 11)
# (episode, tau, score) = (3700, 0.17, 19)
# (episode, tau, score) = (3750, 0.29, 3)
# (episode, tau, score) = (3800, 0.27, 11)
# (episode, tau, score) = (3850, 0.32, -4)
# (episode, tau, score) = (3900, 0.24, 10)
# (episode, tau, score) = (3950, 0.26, 10)
# (episode, tau, score) = (4000, 0.35, -5)
# (episode, tau, score) = (4050, 0.17, 17)
# (episode, tau, score) = (4100, 0.22, 10)
# (episode, tau, score) = (4150, 0.37, -11)
# (episode, tau, score) = (4200, 0.31, -1)
# (episode, tau, score) = (4250, 0.26, 10)
# (episode, tau, score) = (4300, 0.21, 17)
# (episode, tau, score) = (4350, 0.32, -2)
# (episode, tau, score) = (4400, 0.2, 14)
# (episode, tau, score) = (4450, 0.37, -9)
# (episode, tau, score) = (4500, 0.22, 16)
# (episode, tau, score) = (4550, 0.27, 9)
# (episode, tau, score) = (4600, 0.25, 7)
# (episode, tau, score) = (4650, 0.23, 9)
# (episode, tau, score) = (4700, 0.15, 23)
# (episode, tau, score) = (4750, 0.31, 1)
# (episode, tau, score) = (4800, 0.27, 9)
# (episode, tau, score) = (4850, 0.21, 17)
# (episode, tau, score) = (4900, 0.28, 6)
# (episode, tau, score) = (4950, 0.19, 15)
# (episode, tau, score) = (5000, 0.27, 9)
# (episode, tau, score) = (5050, 0.27, 7)
# (episode, tau, score) = (5100, 0.29, 7)
# (episode, tau, score) = (5150, 0.27, 5)
# (episode, tau, score) = (5200, 0.27, 7)
# (episode, tau, score) = (5250, 0.21, 15)
# (episode, tau, score) = (5300, 0.32, -2)
# (episode, tau, score) = (5350, 0.34, -6)
# (episode, tau, score) = (5400, 0.29, 3)
# (episode, tau, score) = (5450, 0.27, 5)
# (episode, tau, score) = (5500, 0.17, 15)
# (episode, tau, score) = (5550, 0.19, 9)
# (episode, tau, score) = (5600, 0.32, 0)
# (episode, tau, score) = (5650, 0.28, 4)
# (episode, tau, score) = (5700, 0.25, 11)
# (episode, tau, score) = (5750, 0.29, 5)
# (episode, tau, score) = (5800, 0.24, 10)
# (episode, tau, score) = (5850, 0.27, 3)
# (episode, tau, score) = (5900, 0.26, 6)
# (episode, tau, score) = (5950, 0.16, 24)
# (episode, tau, score) = (6000, 0.31, -1)
# (episode, tau, score) = (6050, 0.26, 4)
# (episode, tau, score) = (6100, 0.16, 24)
# (episode, tau, score) = (6150, 0.17, 19)
# (episode, tau, score) = (6200, 0.28, 2)
# (episode, tau, score) = (6250, 0.32, 0)
# (episode, tau, score) = (6300, 0.21, 13)
# (episode, tau, score) = (6350, 0.37, -5)
# (episode, tau, score) = (6400, 0.17, 19)
# (episode, tau, score) = (6450, 0.19, 19)
# (episode, tau, score) = (6500, 0.34, -2)
# (episode, tau, score) = (6550, 0.19, 17)
# (episode, tau, score) = (6600, 0.25, 7)
# (episode, tau, score) = (6650, 0.23, 13)
# (episode, tau, score) = (6700, 0.31, 1)
# (episode, tau, score) = (6750, 0.22, 12)
# (episode, tau, score) = (6800, 0.29, 5)
# (episode, tau, score) = (6850, 0.33, 1)
# (episode, tau, score) = (6900, 0.18, 18)
# (episode, tau, score) = (6950, 0.39, -9)
# (episode, tau, score) = (7000, 0.23, 11)
# (episode, tau, score) = (7050, 0.22, 12)
# (episode, tau, score) = (7100, 0.32, -2)
# (episode, tau, score) = (7150, 0.19, 17)
# (episode, tau, score) = (7200, 0.3, 4)
# (episode, tau, score) = (7250, 0.28, 6)
# (episode, tau, score) = (7300, 0.31, 3)
# (episode, tau, score) = (7350, 0.24, 10)
# (episode, tau, score) = (7400, 0.21, 17)
# (episode, tau, score) = (7450, 0.32, 0)
# (episode, tau, score) = (7500, 0.28, 2)
# (episode, tau, score) = (7550, 0.23, 9)
# (episode, tau, score) = (7600, 0.17, 19)
# (episode, tau, score) = (7650, 0.18, 16)
# (episode, tau, score) = (7700, 0.29, 1)
# (episode, tau, score) = (7750, 0.23, 13)
# (episode, tau, score) = (7800, 0.21, 19)
# (episode, tau, score) = (7850, 0.17, 21)
# (episode, tau, score) = (7900, 0.32, 0)
# (episode, tau, score) = (7950, 0.37, -9)
# (episode, tau, score) = (8000, 0.24, 10)
# (episode, tau, score) = (8050, 0.3, 2)
# (episode, tau, score) = (8100, 0.28, 2)
# (episode, tau, score) = (8150, 0.25, 9)
# (episode, tau, score) = (8200, 0.21, 9)
# (episode, tau, score) = (8250, 0.25, 11)
# (episode, tau, score) = (8300, 0.22, 12)
# (episode, tau, score) = (8350, 0.23, 13)
# (episode, tau, score) = (8400, 0.3, 2)
# (episode, tau, score) = (8450, 0.33, -1)
# (episode, tau, score) = (8500, 0.26, 6)
# (episode, tau, score) = (8550, 0.17, 17)
# (episode, tau, score) = (8600, 0.23, 11)
# (episode, tau, score) = (8650, 0.15, 23)
# (episode, tau, score) = (8700, 0.3, 6)
# (episode, tau, score) = (8750, 0.29, 1)
# (episode, tau, score) = (8800, 0.32, 0)
# (episode, tau, score) = (8850, 0.24, 12)
# (episode, tau, score) = (8900, 0.32, 2)
# (episode, tau, score) = (8950, 0.21, 15)
# (episode, tau, score) = (9000, 0.37, -9)
# (episode, tau, score) = (9050, 0.21, 15)
# (episode, tau, score) = (9100, 0.17, 23)
# (episode, tau, score) = (9150, 0.19, 19)
# (episode, tau, score) = (9200, 0.26, 6)
# (episode, tau, score) = (9250, 0.2, 14)
# (episode, tau, score) = (9300, 0.22, 12)
# (episode, tau, score) = (9350, 0.26, 6)
# (episode, tau, score) = (9400, 0.34, -4)
# (episode, tau, score) = (9450, 0.09, 31)
# (episode, tau, score) = (9500, 0.13, 27)
# (episode, tau, score) = (9550, 0.34, -2)
# (episode, tau, score) = (9600, 0.31, 3)
# (episode, tau, score) = (9650, 0.37, -7)
# (episode, tau, score) = (9700, 0.19, 19)
# (episode, tau, score) = (9750, 0.31, 1)
# (episode, tau, score) = (9800, 0.24, 10)
# (episode, tau, score) = (9850, 0.24, 10)
# (episode, tau, score) = (9900, 0.13, 29)
# (episode, tau, score) = (9950, 0.21, 17)
# (episode, tau, score) = (10000, 0.17, 23)

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

plt.plot(running_mean(scores,100))

plt.plot([tau_random for i in scores],'g-')
plt.plot([tau_optimal for i in scores],'r-')

# %% [markdown]
# 1. The DQN agent was much better. In 100 episodes it solved the problem.
# 2. The problem of course is the illegal moves -- maybe I should just hard code them out
# 3. It does the same as random
#
# ### Compare to regular policy gradients

# %% [markdown]
# Looks good -- there is indeed smaller variance.

# %% [markdown]
# ### Hyper parameter optimization

# %%
def run(lr,gamma):
    
    
    #Environment
    n = 4
    G = f.make_G(n)
    state_zero = np.array([1 if i == 0 else 0 for i in range(G.number_of_nodes())])
    env = Env(G,state_zero)
    num_states = env.num_states
    num_actions = env.num_actions

    #Agent
    agent = Agent(num_states, num_actions, lr, gamma)
    agent.memory_size = 1000

    scores = []
    EPISODES = 4000

    for e in range(1,EPISODES+1):
        state = state_zero
        state = np.reshape(state, [1, num_states])
        reward_sum = 0
        while agent.active_time < 100:

            # env.render()
            action = agent.act(state)
            next_state, reward = env.step(action,agent)
            reward_sum += reward
            next_state = np.reshape(next_state, [1, num_states])

            #We only want to remember action taken when looking
            if agent.state == 'serving':
                pass
            else:
                agent.remember(state[0], action, 1.0*reward)
            state = next_state
            

        #Learn & print results
        agent.train_models()
        tau = agent.find_tau()
        scores.append(tau)
        agent.reset_clocks()
        
    return scores

# %%
gammas = [0.1,0.5,0.9,0.99]
lrs = [0.0001,0.001,0.01,0.1,1]

scores_all = []

for lr in lrs:
    for gamma in gammas:
        scores = run(lr,gamma)
        scores_all.append(scores)
        print '(lr,gamma,mean,var) = ' +str((lr,gamma,np.mean(scores), np.std(scores)))
# Out:
# (lr,gamma,mean,var) = (0.0001, 0.1, 0.1810125, 0.054363589319966724)
# (lr,gamma,mean,var) = (0.0001, 0.5, 0.17823000000000003, 0.05313160170745843)
# (lr,gamma,mean,var) = (0.0001, 0.9, 0.21724500000000002, 0.056925916549494394)
# (lr,gamma,mean,var) = (0.0001, 0.99, 0.23560250000000002, 0.05945113113936521)
