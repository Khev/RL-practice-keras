# %% [markdown]
# # Introduction
#
# Here I'm testing the A2C on the "real-world" nyc graph. That is, I place the empirical trips on the manhattan street network, at the empirical times

# %%
import funcs as f
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from agent_with_baseline import Agent
from agent_taxi import PolicyCab
import real_world_nyc_environment as t
from keras.utils import to_categorical

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %matplotlib inline



#Load in data
G = t.get_subgraph()  #start with a subgraph
#trip_data = t.get_tripdata(G,18,18) #monday, the 18th of jan
trip_data = np.loadtxt('data/trip_data_nyc_day_18.txt')
#env = Env(G,state_zero)

#Environment parameters
delta = 30  #trips wait 30 deci-seconds = 5 minutes before disappearing
time_per_episode = 360  #one day

state_zero = np.random.choice(G.nodes())
env = t.Env(G,trip_data,state_zero)
# Out:
# /home/kokeeffe/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Model cab

# %%
trip_probs = t.find_trip_probs(G,trip_data)
p = np.array(trip_probs.values())  #trip probs
optimal_policy = t.find_optimal_policy(p,G)

# %%
#Instantiate
np.random.seed(0)
state_zero = np.random.choice(G.nodes())
env = t.Env(G,trip_data,state_zero)
env.delta = delta
model_cab = t.Modelcab(optimal_policy)


# Main 
state = state_zero
Return = 0  # sum of rewards
while env.active_time <= time_per_episode:
    action = model_cab.act(state)
    next_state, reward = env.step_modelcab(action)  #different step functions for these cabs
    state = next_state
    Return += reward
tau_optimal = 1.0*env.idle_time / env.active_time
print 'rel idle time = ' + str(tau_optimal)
# Out:
# rel idle time = 0.2520775623268698

# %% [markdown]
# ### Greedy cab

# %%
greedy_policy = t.find_greedy_policy(trip_probs,G)

#Instantiate
np.random.seed(0)
state_zero = np.random.choice(G.nodes())
env = t.Env(G,trip_data,state_zero)
env.delta = delta
greedy_cab = t.Modelcab(greedy_policy)


# Main 
state = state_zero
while env.active_time <= time_per_episode:
    action = greedy_cab.act(state)
    next_state, reward = env.step_modelcab(action)
    state = next_state
tau_greedy = 1.0*env.idle_time / env.active_time
print 'rel idle time = ' + str(tau_greedy)
# Out:
# rel idle time = 0.8216867469879519

# %% [markdown]
# ### Random cab

# %%
# Here I will input a random action manually, staying within the framework of an A2C agent.


#Environment
state_zero_scalar = np.random.choice(G.nodes())
env = t.Env(G,trip_data,state_zero_scalar)
state_zero = env.convert(state_zero_scalar)  #convert to 1-hot vector
env.delta = delta
num_states = env.num_states
num_actions = env.num_actions


#Agent
lr = 0.001
gamma = 0.01
agent = Agent(num_states, num_actions, lr, gamma)
agent.memory_size = 1000


#Train
EPISODES = 100
scores_random = []
for e in range(1,EPISODES+1):
    state = state_zero 
    state = np.reshape(state, [1, num_states])  #convert to tensor for keras
    reward_sum = 0
    while env.active_time < 100:
        
        # env.render()
        action = agent.act(state)
        action = np.random.choice(range(num_actions))
        next_state_scalar, reward = env.step(action)
        next_state = env.convert(next_state_scalar)    #convert to 1-hot vec
        reward_sum += reward
        next_state = np.reshape(next_state, [1, num_states])  #convert to tensor for keras
        agent.remember(state[0], action, 1.0*reward)
        state = next_state
    
    #Learn & print results
    tau = env.find_tau()
    scores_random.append(tau)
    env.reset(state_zero_scalar,trip_data)
    if e % 50 == 0:
        print '(episode, tau, score) = ' + str((e,tau,reward_sum))

plt.plot(scores_random)
plt.plot([tau_greedy for i in scores_random],'g-')
plt.plot([tau_optimal for i in scores_random],'r-')
#np.savetxt('stats/scores_lunar_landing.txt',scores)
# Out:
# (episode, tau, score) = (50, 0.5132743362831859, -28829)
# (episode, tau, score) = (100, 0.76, -35940)

# %% [markdown]
# ### RL agent

# %%
#Environment
state_zero_scalar = np.random.choice(G.nodes())
env = t.Env(G,trip_data,state_zero_scalar)
state_zero = env.convert(state_zero_scalar)  #convert to 1-hot vector
env.delta = delta
num_states = env.num_states
num_actions = env.num_actions

env.illegal_move_penalty = 0


#Agent
lr = 0.01
gamma = 0.1
agent = Agent(num_states, num_actions, lr, gamma)
agent.memory_size = 1000

#Train
EPISODES = 5000
scores = []
for e in range(1,EPISODES+1):
    state = state_zero 
    state = np.reshape(state, [1, num_states])  #convert to tensor for keras
    reward_sum = 0
    while env.active_time < 360:
        
        # env.render()
        action = agent.act(state)
        next_state_scalar, reward = env.step(action)
        next_state = env.convert(next_state_scalar)    #convert to 1-hot vec
        reward_sum += reward
        next_state = np.reshape(next_state, [1, num_states])  #convert to tensor for keras
        agent.remember(state[0], action, 1.0*reward)
        state = next_state
    
    #Learn & print results
    agent.train_models()
    tau = env.find_tau()
    scores.append(tau)
    env.reset(state_zero_scalar,trip_data)
    if e % 50 == 0:
        print '(episode, tau, score) = ' + str((e,tau,reward_sum))

        
plt.plot(scores,alpha=0.5)
plt.plot(running_mean(scores,100),'b--')
plt.plot([tau_greedy for i in scores],'g--')
plt.plot([tau_optimal for i in scores],'r--')
plt.legend(['A2C','greedy','optimal'])
#np.savetxt('stats/scores_lunar_landing.txt',scores)
# Out:
# (episode, tau, score) = (50, 0.5097560975609756, 577)
# (episode, tau, score) = (100, 0.5305555555555556, 671)
# (episode, tau, score) = (150, 0.5756756756756757, 657)
# (episode, tau, score) = (200, 0.4, 491)
# (episode, tau, score) = (250, 0.5333333333333333, 337)
# (episode, tau, score) = (300, 0.1548223350253807, 853)
# (episode, tau, score) = (350, 0.36944444444444446, 786)
# (episode, tau, score) = (400, 0.21293800539083557, 729)
# (episode, tau, score) = (450, 0.20555555555555555, 834)
# (episode, tau, score) = (500, 0.3152454780361757, 690)
# (episode, tau, score) = (550, 0.34183673469387754, 579)
# (episode, tau, score) = (600, 0.5040431266846361, 730)
# (episode, tau, score) = (650, 0.2861111111111111, 707)
# (episode, tau, score) = (700, 0.2546916890080429, 811)
# (episode, tau, score) = (750, 0.33783783783783783, 984)
# (episode, tau, score) = (800, 0.3525, 492)
# (episode, tau, score) = (850, 0.17054263565891473, 838)
# (episode, tau, score) = (900, 0.3816793893129771, 668)
# (episode, tau, score) = (950, 0.23324396782841822, 920)
# (episode, tau, score) = (1000, 0.5906593406593407, 337)
# (episode, tau, score) = (1050, 0.2923497267759563, 812)
# (episode, tau, score) = (1100, 0.5083333333333333, 474)
# (episode, tau, score) = (1150, 0.26975476839237056, 904)
# (episode, tau, score) = (1200, 0.28055555555555556, 599)
# (episode, tau, score) = (1250, 0.5240641711229946, 472)
# (episode, tau, score) = (1300, 0.5527777777777778, 470)
# (episode, tau, score) = (1350, 0.3472222222222222, 519)
# (episode, tau, score) = (1400, 0.5240641711229946, 477)
# (episode, tau, score) = (1450, 0.43315508021390375, 500)
# (episode, tau, score) = (1500, 0.3155080213903743, 631)
# (episode, tau, score) = (1550, 0.43646408839779005, 680)
# (episode, tau, score) = (1600, 0.2648648648648649, 840)
# (episode, tau, score) = (1650, 0.3041095890410959, 637)
# (episode, tau, score) = (1700, 0.3360655737704918, 829)
# (episode, tau, score) = (1750, 0.31232876712328766, 907)
# (episode, tau, score) = (1800, 0.31398416886543534, 593)
# (episode, tau, score) = (1850, 0.44021739130434784, 552)
# (episode, tau, score) = (1900, 0.3157894736842105, 589)
# (episode, tau, score) = (1950, 0.42191780821917807, 589)
# (episode, tau, score) = (2000, 0.6388888888888888, 445)
# (episode, tau, score) = (2050, 0.7333333333333333, 152)
# (episode, tau, score) = (2100, 0.2613333333333333, 705)
# (episode, tau, score) = (2150, 0.28055555555555556, 601)
# (episode, tau, score) = (2200, 0.17615176151761516, 850)
# (episode, tau, score) = (2250, 0.2328767123287671, 724)
# (episode, tau, score) = (2300, 0.39444444444444443, 504)
# (episode, tau, score) = (2350, 0.3770491803278688, 708)
# (episode, tau, score) = (2400, 0.3770491803278688, 707)
# (episode, tau, score) = (2450, 0.1891891891891892, 1040)
# (episode, tau, score) = (2500, 0.28055555555555556, 600)
# (episode, tau, score) = (2550, 0.28055555555555556, 602)
# (episode, tau, score) = (2600, 0.475, 545)
# (episode, tau, score) = (2650, 0.39166666666666666, 469)
# (episode, tau, score) = (2700, 0.3770491803278688, 706)
# (episode, tau, score) = (2750, 0.3770491803278688, 713)
# (episode, tau, score) = (2800, 0.20277777777777778, 1045)
# (episode, tau, score) = (2850, 0.5191256830601093, 584)
# (episode, tau, score) = (2900, 0.453551912568306, 599)
# (episode, tau, score) = (2950, 0.773224043715847, 155)
# (episode, tau, score) = (3000, 0.42896174863387976, 796)
# (episode, tau, score) = (3050, 0.582010582010582, 513)
# (episode, tau, score) = (3100, 0.192, 1040)
# (episode, tau, score) = (3150, 0.5618279569892473, 415)
# (episode, tau, score) = (3200, 0.5792349726775956, 354)
# (episode, tau, score) = (3250, 0.2632978723404255, 716)
# (episode, tau, score) = (3300, 0.17174515235457063, 949)
# (episode, tau, score) = (3350, 0.1883656509695291, 847)
# (episode, tau, score) = (3400, 0.4342105263157895, 680)
# (episode, tau, score) = (3450, 0.15789473684210525, 956)
# (episode, tau, score) = (3500, 0.4021164021164021, 672)
# (episode, tau, score) = (3550, 0.35128205128205126, 722)
# (episode, tau, score) = (3600, 0.4767123287671233, 584)
# (episode, tau, score) = (3650, 0.3002754820936639, 630)
# (episode, tau, score) = (3700, 0.5833333333333334, 306)
# (episode, tau, score) = (3750, 0.39166666666666666, 480)
# (episode, tau, score) = (3800, 0.32222222222222224, 920)
# (episode, tau, score) = (3850, 0.3526170798898072, 809)
# (episode, tau, score) = (3900, 0.43089430894308944, 417)
# (episode, tau, score) = (3950, 0.24166666666666667, 845)
# (episode, tau, score) = (4000, 0.18559556786703602, 1054)
# (episode, tau, score) = (4050, 0.20652173913043478, 746)
# (episode, tau, score) = (4100, 0.33972602739726027, 620)
# (episode, tau, score) = (4150, 0.2222222222222222, 938)
# (episode, tau, score) = (4200, 0.2493573264781491, 1036)
# (episode, tau, score) = (4250, 0.15425531914893617, 866)
# (episode, tau, score) = (4300, 0.1956521739130435, 952)
# (episode, tau, score) = (4350, 0.5833333333333334, 328)
# (episode, tau, score) = (4400, 0.46111111111111114, 358)
# (episode, tau, score) = (4450, 0.773224043715847, 160)
# (episode, tau, score) = (4500, 0.21236559139784947, 748)
# (episode, tau, score) = (4550, 0.23333333333333334, 1045)
# (episode, tau, score) = (4600, 0.112565445026178, 868)
# (episode, tau, score) = (4650, 0.9166666666666666, -119)
# (episode, tau, score) = (4700, 0.2964824120603015, 1218)
# (episode, tau, score) = (4750, 0.4794520547945205, 640)
# (episode, tau, score) = (4800, 0.1564102564102564, 956)
# (episode, tau, score) = (4850, 0.3767313019390582, 812)
# (episode, tau, score) = (4900, 0.23076923076923078, 946)
# (episode, tau, score) = (4950, 0.4027777777777778, 691)
# (episode, tau, score) = (5000, 0.1518324607329843, 1251)

# %% [markdown]
# 1. Note to self -- I should change the reward to $\tau$ directly
# 2. I'm not sure if doing the illegal moves this was is wise
# 3. Dont forget, this will probably overfit.

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

plt.plot(scores,alpha=0.5)
plt.plot(running_mean(scores,100),'b--')
plt.plot([tau_greedy for i in scores],'g--')
plt.plot([tau_optimal for i in scores],'r--')

# %%
policy = {}
for state_scalar in list(G.nodes()):
    state_vec = np.reshape(env.convert(state_scalar),(1,num_states))
    action_probs = agent.actor.model.predict(state_vec)[0]
    print action_probs
    best_action = np.argmax(action_probs)
    neighbours = G[state_scalar].keys()
    policy[state_scalar] = neighbours[best_action]
# Out:
# [0.03710038 0.12034702 0.83901095 0.0035416 ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-737885ba1aeb> in <module>()
#       6     best_action = np.argmax(action_probs)
#       7     neighbours = G[state_scalar].keys()
# ----> 8     policy[state_scalar] = neighbours[best_action]
#
# IndexError: list index out of range

# %% [markdown]
# Looks like my guy is doing slightly BETTER. Huh. I wonder how differnt their policies are.
